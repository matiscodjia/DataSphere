# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
housing = pd.read_csv('../Datasets/housing.csv')

# %%
housing.plot(kind='scatter',x="longitude",y="latitude", grid=True, s=housing["population"] /110, label="population",c="median_house_value",cmap="jet",legend=True, sharex=False, figsize=(10,7))
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>
